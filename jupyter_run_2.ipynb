# %%
# !python3 main.py --resume=True --use_gpu=False --num_bits_g_t=2 --num_patches=3 --glimpse_scale=2
# Out:
# [*] Model Checkpoint Dir: ./ckpt
# [*] Param Path: ./ckpt/ram_6_8x8_2_3_2_0_params.json
# [*] Loading model from ./ckpt
# [*] Loaded ram_6_8x8_2_3_2_0_ckpt.pth.tar checkpoint @ epoch 38
#
# [*] Train on 54000 samples, validate on 6000 samples
#
# Epoch: 39/200 - LR: 0.000300
# 56.4s - loss: 0.158 - acc: 94.643: 100%|█| 54000/54000 [00:56<00:00, 956.93it/s]
# train loss: 0.144 - train acc: 96.446 - val loss: 0.178 - val acc: 95.717 - val err: 4.283
#
# Epoch: 40/200 - LR: 0.000300
# 52.8s - loss: 0.043 - acc: 99.107: 100%|█| 54000/54000 [00:52<00:00, 1021.49it/s
# train loss: 0.148 - train acc: 96.313 - val loss: 0.209 - val acc: 95.133 - val err: 4.867
#
# Epoch: 41/200 - LR: 0.000300
# 42.7s - loss: 0.165 - acc: 95.536: 100%|█| 54000/54000 [00:42<00:00, 1263.14it/s
# train loss: 0.164 - train acc: 95.950 - val loss: 0.214 - val acc: 95.050 - val err: 4.950
#
# Epoch: 42/200 - LR: 0.000300
# 40.6s - loss: 0.291 - acc: 91.964: 100%|█| 54000/54000 [00:40<00:00, 1330.00it/s
# ...

# %%
# !python3 main.py --resume=True --use_gpu=False --num_bits_g_t=2 --num_patches=3 --glimpse_scale=2 --is_train=False
# Out:
# [*] Loading model from ./ckpt
# [*] Loaded ram_6_8x8_2_3_2_0_model_best.pth.tar checkpoint @ epoch 183 with best valid acc of 97.550
# [*] Test Acc: 9734/10000 (97.34% - 2.66%)
# Test time:  3.420984983444214
