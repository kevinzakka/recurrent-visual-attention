# %%
# !python3 main.py --resume=True --use_gpu=False --num_bits_h_t=3 --num_patches=3 --glimpse_scale=2 --patch_size=8
# Out:
# [*] Model Checkpoint Dir: ./ckpt
# [*] Param Path: ./ckpt/ram_6_8x8_2_3_0_3_params.json
# [*] Loading model from ./ckpt
# [*] Loaded ram_6_8x8_2_3_0_3_ckpt.pth.tar checkpoint @ epoch 21
#
# [*] Train on 54000 samples, validate on 6000 samples
#
# Epoch: 22/200 - LR: 0.000300
# 55.3s - loss: 2.286 - acc: 20.536: 100%|█| 54000/54000 [00:55<00:00, 975.45it/s]
# train loss: 2.339 - train acc: 21.435 - val loss: 2.330 - val acc: 21.567 - val err: 78.433
#
# Epoch: 23/200 - LR: 0.000300
# 54.9s - loss: 2.332 - acc: 17.857: 100%|█| 54000/54000 [00:54<00:00, 983.53it/s]
# train loss: 2.338 - train acc: 20.731 - val loss: 2.332 - val acc: 21.000 - val err: 79.000
#
# Epoch: 24/200 - LR: 0.000300
# 44.5s - loss: 2.366 - acc: 21.429: 100%|█| 54000/54000 [00:44<00:00, 1212.86it/s
# train loss: 2.331 - train acc: 21.594 - val loss: 2.343 - val acc: 22.083 - val err: 77.917 [*]
#
# Epoch: 25/200 - LR: 0.000300
# 42.4s - loss: 2.352 - acc: 17.857: 100%|█| 54000/54000 [00:42<00:00, 1271.45it/s
# ...

# %%
# !python3 main.py --resume=True --use_gpu=False --num_bits_h_t=3 --num_patches=3 --glimpse_scale=2 --patch_size=8 --is_train=False
# Out:
# [*] Loading model from ./ckpt
# [*] Loaded ram_6_8x8_2_3_0_3_model_best.pth.tar checkpoint @ epoch 131 with best valid acc of 26.817
# [*] Test Acc: 2528/10000 (25.28% - 74.72%)
# Test time:  5.293717622756958

# %%
# !python3 main.py --resume=True --use_gpu=False --num_patches=1 --glimpse_scale=1 --patch_size=8 --num_glimpses=1 --patch_size=2
# Out:
# [*] Model Checkpoint Dir: ./ckpt
# [*] Param Path: ./ckpt/ram_1_2x2_1_1_0_0_params.json
# [*] Loading model from ./ckpt
# [*] Loaded ram_1_2x2_1_1_0_0_ckpt.pth.tar checkpoint @ epoch 155
#
# [*] Train on 54000 samples, validate on 6000 samples
#
# Epoch: 156/200 - LR: 0.000000
# 6.7s - loss: 2.384 - acc: 20.536: 100%|█| 54000/54000 [00:06<00:00, 8012.49it/s]
# train loss: 2.268 - train acc: 19.474 - val loss: 2.280 - val acc: 19.317 - val err: 80.683
#
# Epoch: 157/200 - LR: 0.000000
# 4.3s - loss: 2.309 - acc: 21.429: 100%|█| 54000/54000 [00:04<00:00, 12410.38it/s
# train loss: 2.269 - train acc: 19.302 - val loss: 2.273 - val acc: 19.500 - val err: 80.500
#
# Epoch: 158/200 - LR: 0.000000
# 4.5s - loss: 2.294 - acc: 16.071: 100%|█| 54000/54000 [00:04<00:00, 12022.31it/s
# train loss: 2.273 - train acc: 18.972 - val loss: 2.268 - val acc: 18.800 - val err: 81.200
#
# Epoch: 159/200 - LR: 0.000000
# 4.5s - loss: 2.223 - acc: 16.964: 100%|█| 54000/54000 [00:04<00:00, 11888.10it/s
# ...
